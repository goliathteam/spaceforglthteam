# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import io
import os
import sqlite3

# %%
def extract_features(bs_content, contextRef, fund_id):
    
    #General Description
    try:
        general = bs_content.find_all('CategoriaFIM')[0].text.split('\n')
        fund_type = general[1]
        fund_focus = general[2]
        fund_risk = general[3]    
    except:
        fund_type = np.nan
        fund_focus = np.nan
        fund_risk = np.nan        
    
    #AUM
    try:
        all_aum = bs_content.find_all('Patrimonio', {'contextRef': contextRef + '_ia'})
        aum = sum([float(i.text) for i in all_aum])
    except:
        aum = np.nan
    
    #Shareholders
    try:
        all_sh = bs_content.find_all('NumeroParticipes', {'contextRef': contextRef + '_ia'})
        sh = sum([float(i.text) for i in all_sh])    
    except:
        sh = np.nan  
    
    #Fees
    try:
        all_fees = bs_content.find_all('ComisionGestionCobrada', {'contextRef': contextRef + '_daa'})
        fees = np.mean([float(i.text) for i in all_fees])
    except:
        fees = np.nan    
    
    #Portfolio Rotation
    try:
        all_port_rot = bs_content.find_all('IndiceRotacionCartera', {'contextRef': contextRef + '_da'})
        port_rot = np.mean([float(i.text) for i in all_port_rot])
    except:
        port_rot = np.nan
    
    #Investment Policy
    try:
        inv_pol = bs_content.find_all('PoliticaInversion')[0].text.replace('\n', '').encode('latin-1').decode('utf-8')
    except:
        inv_pol = bs_content.find_all('PoliticaInversion')[0].text.replace('\n', '')
    
    df_features = pd.DataFrame(data={'Fund ID': fund_id, 'Fund Type': fund_type, 'Fund Focus': fund_focus, 'Fund Risk': fund_risk,
                                     'AUM': aum, 'Fees': fees, 'Rotation': port_rot, 'Inv Policy': inv_pol}, index=[0])
    
    return df_features

# %%
Global_df = pd.read_excel('CNMV_Global_Scrape.xlsx')
Global_df.head(10)
# Out:
#   Type                               AM Name  AM Code  \
# 0  IIC                  360 CORA SGIIC, S.A.      276
# 1  IIC                 A&G FONDOS, SGIIC, SA      195
# 2  IIC                 A&G FONDOS, SGIIC, SA      195
# 3  IIC                 A&G FONDOS, SGIIC, SA      195
# 4  IIC                 A&G FONDOS, SGIIC, SA      195
# 5  IIC                 A&G FONDOS, SGIIC, SA      195
# 6  IIC                 A&G FONDOS, SGIIC, SA      195
# 7  IIC            ABACO CAPITAL, SGIIC, S.A.      238
# 8  IIC            ABACO CAPITAL, SGIIC, S.A.      238
# 9  IIC  ABANTE ASESORES GESTION, SGIIC, S.A.      194
#
#                                      Global Data URL  \
# 0  https://www.cnmv.es/Portal/Consultas/IIC/SGIIC...
# 1  https://www.cnmv.es/Portal/Consultas/IIC/SGIIC...
# 2  https://www.cnmv.es/Portal/Consultas/IIC/SGIIC...
# 3  https://www.cnmv.es/Portal/Consultas/IIC/SGIIC...
# 4  https://www.cnmv.es/Portal/Consultas/IIC/SGIIC...
# 5  https://www.cnmv.es/Portal/Consultas/IIC/SGIIC...
# 6  https://www.cnmv.es/Portal/Consultas/IIC/SGIIC...
# 7  https://www.cnmv.es/Portal/Consultas/IIC/SGIIC...
# 8  https://www.cnmv.es/Portal/Consultas/IIC/SGIIC...
# 9  https://www.cnmv.es/Portal/Consultas/IIC/SGIIC...
#
#                              Fund Name  Fund Code  \
# 0                CODEX GLOBAL FUND, FI     5461.0
# 1       A&G RENTA FIJA CORTO PLAZO, FI     3989.0
# 2            GLOBAL MANAGERS FUNDS, FI     3072.0
# 3                GREDOS BOLSA EURO, FI     4881.0
# 4       GREDOS BOLSA INTERNACIONAL, FI     4883.0
# 5                  GREDOS MODERADO, FI     4882.0
# 6                GREDOS RENTA FIJA, FI     5389.0
# 7  ABACO GLOBAL VALUE OPPORTUNITIES FI     4827.0
# 8    ABACO RENTA FIJA MIXTA GLOBAL, FI     4474.0
# 9           ABANTE ASESORES GLOBAL, FI     2562.0
#
#                                      Fund Global URL   Fund ID
# 0  https://www.cnmv.es/Portal/Consultas/IIC/Fondo...  276-5461
# 1  https://www.cnmv.es/Portal/Consultas/IIC/Fondo...  195-3989
# 2  https://www.cnmv.es/Portal/Consultas/IIC/Fondo...  195-3072
# 3  https://www.cnmv.es/Portal/Consultas/IIC/Fondo...  195-4881
# 4  https://www.cnmv.es/Portal/Consultas/IIC/Fondo...  195-4883
# 5  https://www.cnmv.es/Portal/Consultas/IIC/Fondo...  195-4882
# 6  https://www.cnmv.es/Portal/Consultas/IIC/Fondo...  195-5389
# 7  https://www.cnmv.es/Portal/Consultas/IIC/Fondo...  238-4827
# 8  https://www.cnmv.es/Portal/Consultas/IIC/Fondo...  238-4474
# 9  https://www.cnmv.es/Portal/Consultas/IIC/Fondo...  194-2562

# %%
list_files = os.listdir('Info Pública')
list_files.remove('Funds DB')

all_prts = pd.DataFrame(columns=['ISIN', 'Activo', 'Descripción', 'Peso Actual', 'Peso Anterior', 'Fund ID'])

for i_file in list_files:
    
    try:
        #Convert xml format to Beautifulsoup
        content = []
        # Read the XML file        
        with open('Info Pública/' + i_file, 'rb') as file:
            i_bs_content = BeautifulSoup(file.read(), 'xml')        

        #contextRef is an attribute of each file
        #adding '_ia' makes reference to current value and '_ipp' makes reference to past value   
        i_contextRef = i_bs_content.find('context')['id'].replace('_da','')    

        i_port = extract_portfolio(i_bs_content, i_contextRef, i_file.replace('.xml',''))

        all_prts = pd.concat([all_prts, i_port], ignore_index=True)
    
    except:
        continue
    
all_prts.to_pickle('portfolios.pickle')    
all_prts.head(10)

# %%
list_classes

# %%
list_files = os.listdir('Info Pública')
list_files.remove('Funds DB')
list_files
# Out:
# ['103-1081.xml',
#  '103-1230.xml',
#  '103-15.xml',
#  '103-2269.xml',
#  '103-377.xml',
#  '103-4290.xml',
#  '103-4422.xml',
#  '103-502.xml',
#  '103-5172.xml',
#  '103-5279.xml',
#  '103-5330.xml',
#  '103-5417.xml',
#  '103-5467.xml',
#  '103-594.xml',
#  '103-6.xml',
#  '103-75.xml',
#  '105-4869.xml',
#  '105-4991.xml',
#  '105-5040.xml',
#  '105-5049.xml',
#  '105-5087.xml',
#  '105-5105.xml',
#  '105-5278.xml',
#  '105-5309.xml',
#  '105-5338.xml',
#  '105-5392.xml',
#  '105-5401.xml',
#  '105-5426.xml',
#  '105-5437.xml',
#  '105-5438.xml',
#  '105-5439.xml',
#  '105-5440.xml',
#  '105-5441.xml',
#  '105-5447.xml',
#  '113-1067.xml',
#  '113-1083.xml',
#  '113-1110.xml',
#  '113-1115.xml',
#  '113-1377.xml',
#  '113-1536.xml',
#  '113-1777.xml',
#  '113-1786.xml',
#  '113-2222.xml',
#  '113-295.xml',
#  '113-3653.xml',
#  '113-3753.xml',
#  '113-3825.xml',
#  '113-399.xml',
#  '113-4160.xml',
#  '113-4229.xml',
#  '113-4383.xml',
#  '113-4470.xml',
#  '113-470.xml',
#  '113-4718.xml',
#  '113-4789.xml',
#  '113-504.xml',
#  '113-5090.xml',
#  '113-5104.xml',
#  '113-544.xml',
#  '113-722.xml',
#  '113-972.xml',
#  '115-1548.xml',
#  '12-1175.xml',
#  '12-1197.xml',
#  '12-13.xml',
#  '12-1385.xml',
#  '12-1494.xml',
#  '12-154.xml',
#  '12-1584.xml',
#  '12-1920.xml',
#  '12-1973.xml',
#  '12-1988.xml',
#  '12-1998.xml',
#  '12-2011.xml',
#  '12-205.xml',
#  '12-208.xml',
#  '12-2156.xml',
#  '12-2164.xml',
#  '12-2227.xml',
#  '12-2231.xml',
#  '12-2295.xml',
#  '12-231.xml',
#  '12-2314.xml',
#  '12-2348.xml',
#  '12-24.xml',
#  '12-2410.xml',
#  '12-2443.xml',
#  '12-2544.xml',
#  '12-258.xml',
#  '12-26.xml',
#  '243-2733.xml',
#  '243-3068.xml',
#  '243-3354.xml',
#  '243-3355.xml',
#  '243-3356.xml',
#  '243-3394.xml',
#  '243-4278.xml',
#  '243-4619.xml',
#  '243-5065.xml',
#  '243-5089.xml',
#  '243-5366.xml',
#  '243-5481.xml',
#  '243-5482.xml',
#  '243-5496.xml',
#  '243-860.xml',
#  '243-861.xml',
#  '243-987.xml',
#  '243-989.xml',
#  '246-4359.xml',
#  '246-5238.xml',
#  '246-59.xml',
#  '247-46.xml',
#  '247-47.xml',
#  '248-5127.xml',
#  '248-5164.xml',
#  '248-5434.xml',
#  '248-5436.xml',
#  '248-58.xml',
#  '248-65.xml',
#  '249-5325.xml',
#  '249-5444.xml',
#  '251-5075.xml',
#  '251-5129.xml',
#  '251-5130.xml',
#  '251-5131.xml',
#  '251-5132.xml',
#  '251-64.xml',
#  '252-5200.xml',
#  '252-5209.xml',
#  '253-5322.xml',
#  '253-62.xml',
#  '253-71.xml',
#  '254-5487.xml',
#  '255-5244.xml',
#  '256-5202.xml',
#  '256-5203.xml',
#  '256-5204.xml',
#  '256-5429.xml',
#  '257-5360.xml',
#  '258-4863.xml',
#  '258-5159.xml',
#  '258-5160.xml',
#  '258-5409.xml',
#  '258-5469.xml',
#  '259-5388.xml',
#  '260-40.xml',
#  '261-5307.xml',
#  '262-4801.xml',
#  '262-4910.xml',
#  '262-4911.xml',
#  '262-4952.xml',
#  '263-5267.xml',
#  '263-5269.xml',
#  '264-5289.xml',
#  '264-5290.xml',
#  '264-5291.xml',
#  '265-5391.xml',
#  '266-4710.xml',
#  '266-5458.xml',
#  '267-5313.xml',
#  '268-5411.xml',
#  '268-5416.xml',
#  '268-70.xml',
#  '269-5222.xml',
#  '269-5224.xml',
#  '269-5365.xml',
#  '270-5484.xml',
#  '271-5367.xml',
#  '271-5370.xml',
#  '272-5410.xml',
#  '272-5419.xml',
#  '273-74.xml',
#  '273-85.xml',
#  '274-1392.xml',
#  '276-5461.xml',
#  '277-4231.xml',
#  '29-1174.xml',
#  '29-1268.xml',
#  '29-1474.xml',
#  '29-1475.xml',
#  '29-1508.xml',
#  ...]

# %%
i_fund = list_files[0].replace('.xml','')
i_fund
# Out:
# '103-1081'

# %%
i_fund = '12-4252'

# %%
#Get in the Fund Display and go to the tab 'Clases de participaciones sin compartimentos'
soup = BeautifulSoup(requests.get(Global_df[Global_df['Fund ID'].isin([i_fund])]['Fund Global URL'].values[0]).content, 'lxml')
soup_link_fund = soup.find('div', {'class': 'NavegApdo'}).find_all('a', href=True)

for i_links in soup_link_fund:
    if i_links.text=='Clases de participaciones sin compartimentos':
        link_isins = i_links['href']

#SI SOLO HAY UNA CLASE PETA AQUI!!!!!!!!!!!!!!!!!!!!!!!!        
link_isins = '/'.join(Global_df[Global_df['Fund ID'].isin([i_fund])]['Global Data URL'].values[0].split('/')[:-1]) + '/' + link_isins        
        
#Once inside the tab 'Clases de participaciones sin compartimentos', get the ISIN of each class 
soup = BeautifulSoup(requests.get(link_isins).content, 'lxml')
list_classes = [i.text for i in soup.find_all('td', {'data-th': 'Denominación'})]
list_isins = [i.text for i in soup.find_all('td', {'data-th': 'ISIN'})]

# %%
list_isins
